# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.strtree import STRtree
from shapely.ops import unary_union
from datetime import timedelta
import pandas as pd
import numpy as np

# %%
# raw TWIG (treatment) data
data = gpd.read_file('/oak/stanford/groups/konings/ashdef/TWIG/treatment_index.gdb')
# Out:
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:198: RuntimeWarning: organizePolygons() received a polygon with more than 100 parts. The processing may be really slow.  You can skip the processing by setting METHOD=SKIP, or only make it analyze counter-clock wise parts by setting METHOD=ONLY_CCW if you can assume that the outline of holes is counter-clock wise defined
#   return ogr_read(

# %% [markdown]
# # Checking for overlapping treatment activities, filtering out overlaps, & figuring out the time gap between overlapping activities

# %%
# filtering twig data to only include treatments in the western us
western_states = ['CA', 'OR', 'WA', 'ID', 'MT', 'WY', 'UT', 'AZ', 'CO', 'NM']

wus_trmts = data[data['state'].isin(western_states)]
wus_trmts.shape
wus_trmts.columns
# Out:
# Index(['unique_id', 'name', 'state', 'acres', 'treatment_date', 'date_source',
#        'identifier_database', 'date_current', 'actual_completion_date',
#        'activity_code', 'activity', 'method', 'equipment', 'category', 'type',
#        'twig_category', 'agency', 'fund_source', 'fund_code', 'total_cost',
#        'cost_per_uom', 'uom', 'error', 'shape_Length', 'shape_Area',
#        'geometry'],
#       dtype='object')

# %% [markdown]
# https://deepwiki.com/shapely/shapely/8.1-strtree-implementation

# %%
# spatial indices for treatment polygons - used help from chatGPT for this cell and next
geoms = list(wus_trmts.geometry)
tree = STRtree(geoms)

# %%
non_overlapping = [] # list of indices for polygons that aren't overlapping another

time_diffs = []  # store time differences in days between overlapping treatments
overlapping = [] # list of indices for polygons that are overlapping another


#loop over treatment polygons
for i, geom in enumerate(geoms):
    # which polygons maybe intersect?
    possible_matches_idx = tree.query(geom) # this returns indices, not geometries

    # check each possible match
    overlaps = False
    for j in possible_matches_idx:
        if i == j: # skip if the current polygon is being looked at
            continue  

        # if polygons do intersect, check how far apart the treatment dates are
        if geom.intersects(geoms[j]):
            overlaps = True
            
            date_i = wus_trmts['treatment_date'].iloc[i]
            date_j = wus_trmts['treatment_date'].iloc[j]

            # calculate  time difference
            delta = abs((date_i - date_j).days)
            time_diffs.append(delta)
            overlapping.append((i, j)) 
            
            break  

    if not overlaps:
        non_overlapping.append(i)

# filter out the original geodataframe to only include unique treatment areas
wus_trmts_unique = wus_trmts.iloc[non_overlapping]


#wus_trmts_unique.to_file("wus_trmts_unique.shp")

# %%
time_diffs = pd.read_csv("time_diffs.txt", header=None)[0].tolist()
np.mean(time_diffs)
# Out:
# 2946.1301928674998

# %%
time_diffs = np.array(time_diffs)

# %%
time_diffs_1day = time_diffs[time_diffs == 1]
print(len(time_diffs_1day))
print("% overlapping treatments 1 day apart = ", len(time_diffs_1day)/len(time_diffs)*100)
# Out:
# 4169
# % overlapping treatments 1 day apart =  0.420074503019317

# %%
time_diffs_3day = time_diffs[time_diffs <4]
print(len(time_diffs_3day))
print("% overlapping treatments 3 days apart or less ", len(time_diffs_3day)/len(time_diffs)*100)
# Out:
# 178024
# % overlapping treatments 3 days apart or less  17.93795714212302

# %%
time_diffs_1yr = time_diffs_years[time_diffs_years<1]
len(time_diffs_1yr)
# Out:
# 306652

# %%
plt.figure(figsize=(8,5))

time_diffs_years = np.array(time_diffs) / 365

# one bar per year
plt.hist(time_diffs_years, bins=int(time_diffs_years.max()), edgecolor='black')
plt.xlim(0, 55)
plt.xlabel("Years")
plt.ylabel("Frequency")
plt.title("Distribution of Time Gaps Between Overlapping Treatments")
print("% overlapping treatments < 1 yr apart = ", len(time_diffs_1yr)/len(time_diffs_years)*100)
# Out:
# % overlapping treatments < 1 yr apart =  30.898701487138304

# %%
time_diffs_1month = time_diffs_years[time_diffs_years<1/12]
len(time_diffs_1month)
print("% overlapping treatments < 1 month apart = ", len(time_diffs_1month)/len(time_diffs_years)*100)
# Out:
# 196169

# %%
time_diffs_1week = time_diffs_years[time_diffs_years<1/52]
print(len(time_diffs_1week))
print("% overlapping treatments < 1 week apart = ", len(time_diffs_1week)/len(time_diffs_years)*100)
# Out:
# 181109
# % overlapping treatments < 1 week apart =  18.24880622867006

# %%
wus_trmts_unique = gpd.read_file("/home/users/ashdef/TWIG_SFE/TWIG_no_overlap/wus_trmts_unique.shp")
wus_trmts_unique
# Out:
#                   unique_id                     name state    acres  \
# 0       AC30515201035510355       TSMRS LEGACY STAND    MT   25.387
# 1       AC37088401036110361       TSMRS LEGACY STAND    ID   27.989
# 2       AC79680901035910359       TSMRS LEGACY STAND    ID   22.093
# 3       AC13334901027710277       TSMRS LEGACY STAND    ID   38.625
# 4      AC101483401035910359               PACKER CRK    ID   32.604
# ...                     ...                      ...   ...      ...
# 27124         7122137010602      SERAL RUSHING FR F7    CA   12.908
# 27125         6956726010602            CHILCOOT FIRE    ID  347.988
# 27126       AC1770461010602  TOBOGGAN RIDGE FUELS 06    ID  470.795
# 27127       AC1976893010602                     None    WY    3.182
# 27128         3457250010602      MILL CREEK RX UNIT3    WY    0.805
#
#       treatment_        date_sourc               identifier date_curre  \
# 0     2002-08-01    date_completed  FACTS Common Attributes 2022-09-08
# 1     1990-09-01    date_completed  FACTS Common Attributes 2022-09-08
# 2     2005-04-04  act_created_date  FACTS Common Attributes 2022-09-08
# 3     1985-10-01    date_completed  FACTS Common Attributes 2022-09-08
# 4     2005-04-06  act_created_date  FACTS Common Attributes 2025-02-18
# ...          ...               ...                      ...        ...
# 27124 2024-09-23      date_planned    FACTS Hazardous Fuels 2025-02-14
# 27125 2023-11-30    date_completed    FACTS Hazardous Fuels 2025-02-14
# 27126 2008-07-01    date_completed    FACTS Hazardous Fuels 2025-02-14
# 27127 2010-10-20    date_completed    FACTS Hazardous Fuels 2025-02-14
# 27128 2011-10-19    date_completed    FACTS Hazardous Fuels 2025-02-14
#
#       actual_com activity_c  ... agency                 fund_sourc fund_code  \
# 0     2002-08-01       1117  ...   USFS                      Other      NFND
# 1     1990-09-01       1113  ...   USFS  Hazardous Fuels Reduction      WFHF
# 2            NaT       4521  ...   USFS                      Other      NFVW
# 3     1985-10-01       1130  ...   USFS                      Other      NFVW
# 4            NaT       4521  ...   USFS                      Other      NFVW
# ...          ...        ...  ...    ...                        ...       ...
# 27124        NaT       1160  ...   USFS                        BIL      HX08
# 27125 2023-11-30       1117  ...   USFS                      Other      WFSE
# 27126 2008-07-01       6101  ...   USFS  Hazardous Fuels Reduction      WFHF
# 27127 2010-10-20       4521  ...   USFS                      Other      NFVW
# 27128 2011-10-19       1111  ...   USFS                      Other      WFXF
#
#       total_cost cost_per_u    uom error    shape_Leng    shape_Area  \
# 0          0.000        0.0  ACRES  None   3045.317914  2.086794e+05
# 1          0.000        0.0  ACRES  None   2228.254965  2.376036e+05
# 2          0.000        0.0  ACRES  None   1989.757513  1.972523e+05
# 3       3283.125       85.0  ACRES  None   3220.730703  3.222062e+05
# 4          0.000        0.0  ACRES  None   2597.335119  3.031142e+05
# ...          ...        ...    ...   ...           ...           ...
# 27124        NaN        NaN  ACRES  None   1827.315424  8.451129e+04
# 27125  86997.000      250.0  ACRES  None  19688.753869  2.792218e+06
# 27126  14123.850       30.0  ACRES  None  11521.115477  4.041538e+06
# 27127    451.844      142.0  ACRES  None    614.972227  2.262978e+04
# 27128     40.250       50.0  ACRES  None    423.591953  5.786079e+03
#
#                                                 geometry
# 0      POLYGON Z ((-11790486.34 5691665.934 -100000, ...
# 1      POLYGON Z ((-12849958.371 5835671.608 -100000,...
# 2      POLYGON Z ((-12938471.414 6057021.115 -100000,...
# 3      POLYGON Z ((-12901453.758 5758169.855 -100000,...
# 4      POLYGON Z ((-13021978.102 6230886.77 -100000, ...
# ...                                                  ...
# 27124  POLYGON Z ((-13374868.486 4595103.961 -100000,...
# 27125  MULTIPOLYGON Z (((-12843501.957 5582861.543 -1...
# 27126  POLYGON Z ((-12806943.552 5883334.734 -100000,...
# 27127  POLYGON Z ((-11829665.679 5012370.196 -100000,...
# 27128  POLYGON Z ((-11813087.771 5067130.862 -100000,...
#
# [27129 rows x 26 columns]

# %%
wus_trmts_unique.columns
# Out:
# Index(['unique_id', 'name', 'state', 'acres', 'treatment_', 'date_sourc',
#        'identifier', 'date_curre', 'actual_com', 'activity_c', 'activity',
#        'method', 'equipment', 'category', 'type', 'twig_categ', 'agency',
#        'fund_sourc', 'fund_code', 'total_cost', 'cost_per_u', 'uom', 'error',
#        'shape_Leng', 'shape_Area', 'geometry'],
#       dtype='object')

# %%
grouped = wus_trmts_unique.groupby(['state', 'twig_categ']).size().reset_index(name='count')

pivot_df = grouped.pivot(index='state', columns='twig_categ', values='count').fillna(0)

plt.figure(figsize=(12, 8))
pivot_df.plot(kind='bar', stacked=True, colormap='tab20', figsize=(14, 8))
plt.xticks(rotation = 0)
plt.ylabel('Number of Sites', fontsize = 16)
plt.title('All WUS Wildfire Treatment Sites, no overlap', fontsize = 20)
plt.legend(title='Twig Category', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

# %% [markdown]
# ## Refining above filtering to only eliminate overlapping treatment activities > 3 days apart, based on time gap analysis

# %%
western_states = ['CA', 'OR', 'WA', 'ID', 'MT', 'WY', 'UT', 'AZ', 'CO', 'NM']

wus_trmts = data[data['state'].isin(western_states)]
wus_trmts.shape
wus_trmts.columns
# Out:
# Index(['unique_id', 'name', 'state', 'acres', 'treatment_date', 'date_source',
#        'identifier_database', 'date_current', 'actual_completion_date',
#        'activity_code', 'activity', 'method', 'equipment', 'category', 'type',
#        'twig_category', 'agency', 'fund_source', 'fund_code', 'total_cost',
#        'cost_per_uom', 'uom', 'error', 'shape_Length', 'shape_Area',
#        'geometry'],
#       dtype='object')

# %%
# spatial indices for treatment polygons
geoms = list(wus_trmts.geometry)
tree = STRtree(geoms)

# %%
non_overlapping = [] # list of indices for polygons that aren't overlapping another

overlapping = [] # list of indices for polygons that are overlapping another


#loop over polygons
for i, geom in enumerate(geoms):
    # which polygons maybe intersect?
    possible_matches_idx = tree.query(geom) # this returns indices, not geometries

    # check each possible match
    overlaps = False
    for j in possible_matches_idx:
        if i == j: # skip if the current polygon is being looked at
            continue  

        # if polygons do intersect, check how far apart the treatment dates are
        if geom.intersects(geoms[j]):
            
            date_i = wus_trmts['treatment_date'].iloc[i]
            date_j = wus_trmts['treatment_date'].iloc[j]

            # calculate  time difference
            delta = abs((date_i - date_j).days)

            if delta > 3: # if the treatment completion dates are more than 3 days apart, consider it overlapping. Do not include either of these sites in treatment data
                overlaps = True
                overlapping.append((i, j))                 
                
            break  

    if not overlaps:
        non_overlapping.append(i) # this will now include intersecting treatments that occurred within 3 days

# filter out the original geodataframe to only include unique treatment areas
wus_trmts_unique_3day = wus_trmts.iloc[non_overlapping]


wus_trmts_unique_3day.to_file("wus_trmts_unique_3day.shp")
# Out:
# /tmp/ipykernel_451/882307300.py:39: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   wus_trmts_unique_3day.to_file("wus_trmts_unique_3day.shp")
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'treatment_date' to 'treatment_'
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field treatment_ create as date field, though DateTime requested.
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'date_source' to 'date_sourc'
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'identifier_database' to 'identifier'
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'date_current' to 'date_curre'
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field date_curre create as date field, though DateTime requested.
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'actual_completion_date' to 'actual_com'
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field actual_com create as date field, though DateTime requested.
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'activity_code' to 'activity_c'
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'twig_category' to 'twig_categ'
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'fund_source' to 'fund_sourc'
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'cost_per_uom' to 'cost_per_u'
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'shape_Length' to 'shape_Leng'
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 271369848.17492718 of field shape_Area of feature 96937 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 114591594.12734444 of field shape_Area of feature 96938 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 679759746.13049245 of field shape_Area of feature 112696 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 165536936.34643292 of field shape_Area of feature 132048 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 257828557.88573274 of field shape_Area of feature 135355 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 163769212.649113 of field shape_Area of feature 135637 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 112671629.93107618 of field shape_Area of feature 135639 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 172597204.52339754 of field shape_Area of feature 135640 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 164796518.08584273 of field shape_Area of feature 137572 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1020767828.755384 of field shape_Area of feature 138821 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 185678311.94318396 of field shape_Area of feature 140189 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 112450114.34174129 of field shape_Area of feature 142114 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 106272022.57814845 of field shape_Area of feature 144679 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 107485495.23303689 of field shape_Area of feature 145154 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 164088685.72024676 of field shape_Area of feature 146443 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 164088685.72024676 of field shape_Area of feature 146444 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 109592415.99377863 of field shape_Area of feature 152031 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 157904617.82690918 of field shape_Area of feature 157225 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 208556490 of field total_cost of feature 157332 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 169791183.4295955 of field shape_Area of feature 157332 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 202118285.6193648 of field shape_Area of feature 160657 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 103277773.62047634 of field shape_Area of feature 162434 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 214413070.42399999 of field total_cost of feature 174170 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 310633980.80837029 of field shape_Area of feature 174170 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 131530978.97325122 of field shape_Area of feature 177562 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 121055898.31812391 of field shape_Area of feature 178119 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 281446766.27409136 of field shape_Area of feature 178120 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 206206494.06623197 of field shape_Area of feature 178626 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 105985708.27985971 of field shape_Area of feature 181002 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 191455291.7770015 of field shape_Area of feature 189566 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 131798598.61918792 of field shape_Area of feature 192577 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 165413149.90766165 of field shape_Area of feature 194366 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 113712003.90000001 of field total_cost of feature 194790 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 496511097.47144783 of field shape_Area of feature 197813 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 125965474.98024252 of field shape_Area of feature 200283 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 183200505.85536662 of field shape_Area of feature 203381 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 107739649.84242167 of field shape_Area of feature 204308 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(

# %%
wus_trmts_unique_3day
# Out:
#                    unique_id                 name state   acres  \
# 8        AC31101801036410364   TSMRS LEGACY STAND    MT   9.786
# 10       AC31101701036410364   TSMRS LEGACY STAND    MT   9.786
# 20       AC31928101027710277   TSMRS LEGACY STAND    ID  47.685
# 21       AC11802401025910259   TSMRS LEGACY STAND    MT  14.033
# 26       AC99974101035910359  S FORK GOLD UNIT 13    ID   7.699
# ...                      ...                  ...   ...     ...
# 1374254        6991388010602    WEST CRYSTAL IRSC    CO  26.152
# 1374255        6991389010602    WEST CRYSTAL IRSC    CO  26.152
# 1374271      AC1964770010602   7MILE FRLTSC-TU:07    CO   4.741
# 1374272      AC1964771010602   7MILE FRLTSC-TU:07    CO   4.741
# 1374274        3484779010602   7MILE FRLTSC-TU:07    CO   4.741
#
#                    treatment_date     date_source      identifier_database  \
# 8       2002-09-01 00:00:00+00:00  date_completed  FACTS Common Attributes
# 10      2002-09-01 00:00:00+00:00  date_completed  FACTS Common Attributes
# 20      1990-08-01 00:00:00+00:00  date_completed  FACTS Common Attributes
# 21      2003-09-01 00:00:00+00:00  date_completed  FACTS Common Attributes
# 26      1993-07-01 00:00:00+00:00  date_completed  FACTS Common Attributes
# ...                           ...             ...                      ...
# 1374254 2024-09-01 00:00:00+00:00    date_planned    FACTS Hazardous Fuels
# 1374255 2024-09-01 00:00:00+00:00    date_planned    FACTS Hazardous Fuels
# 1374271 2011-08-15 00:00:00+00:00  date_completed    FACTS Hazardous Fuels
# 1374272 2011-08-15 00:00:00+00:00  date_completed    FACTS Hazardous Fuels
# 1374274 2011-08-15 00:00:00+00:00  date_completed    FACTS Hazardous Fuels
#
#                      date_current    actual_completion_date activity_code  \
# 8       2022-09-08 17:19:43+00:00 2002-09-01 00:00:00+00:00          4494
# 10      2022-09-08 17:18:15+00:00 2002-09-01 00:00:00+00:00          4452
# 20      2022-09-08 17:17:06+00:00 1990-08-01 00:00:00+00:00          4494
# 21      2022-09-08 17:21:37+00:00 2003-09-01 00:00:00+00:00          1117
# 26      2022-09-08 17:15:00+00:00 1993-07-01 00:00:00+00:00          1153
# ...                           ...                       ...           ...
# 1374254 2025-02-14 04:04:05+00:00                       NaT          1160
# 1374255 2025-02-14 04:04:05+00:00                       NaT          1120
# 1374271 2025-02-14 04:04:06+00:00 2011-08-15 00:00:00+00:00          4121
# 1374272 2025-02-14 04:04:06+00:00 2011-08-15 00:00:00+00:00          1120
# 1374274 2025-02-14 04:04:06+00:00 2011-08-15 00:00:00+00:00          1153
#
#          ... agency                fund_source fund_code   total_cost  \
# 8        ...   USFS                      Other      CONT      0.00000
# 10       ...   USFS                      Other      NFND      0.00000
# 20       ...   USFS                      Other      PPPP      0.00000
# 21       ...   USFS                      Other      NFND      0.00000
# 26       ...   USFS                      Other      BDBD   1986.34200
# ...      ...    ...                        ...       ...          ...
# 1374254  ...   USFS                      Other      IRHF  30551.55096
# 1374255  ...   USFS                      Other      IRHF  83686.40000
# 1374271  ...   USFS  Hazardous Fuels Reduction      WFHF   4019.79908
# 1374272  ...   USFS  Hazardous Fuels Reduction      WFHF   4019.79908
# 1374274  ...   USFS  Hazardous Fuels Reduction      WFHF   4019.79908
#
#         cost_per_uom    uom error shape_Length     shape_Area  \
# 8               0.00  ACRES  None  1176.399159   79493.391709
# 10              0.00  ACRES  None  1176.399159   79493.391709
# 20              0.00  ACRES  None  3352.241661  396929.361889
# 21              0.00  ACRES  None  1653.301125  127844.535094
# 26            258.00  ACRES  None  1145.775633   71747.884899
# ...              ...    ...   ...          ...            ...
# 1374254      1168.23  ACRES  None  2175.727791  185344.429244
# 1374255      3200.00  ACRES  None  2175.727791  185344.429244
# 1374271       847.88  ACRES  None   944.777253   33465.909818
# 1374272       847.88  ACRES  None   944.777253   33465.909818
# 1374274       847.88  ACRES  None   944.777253   33465.909818
#
#                                                   geometry
# 8        MULTIPOLYGON Z (((-12393113.55 5637851.893 -10...
# 10       MULTIPOLYGON Z (((-12393113.55 5637851.893 -10...
# 20       MULTIPOLYGON Z (((-12866398.782 5748465.897 -1...
# 21       MULTIPOLYGON Z (((-12675384.798 6144308.149 -1...
# 26       MULTIPOLYGON Z (((-13024178.121 6241008.785 -1...
# ...                                                    ...
# 1374254  MULTIPOLYGON Z (((-11765006.401 4995371.487 -1...
# 1374255  MULTIPOLYGON Z (((-11765006.401 4995371.487 -1...
# 1374271  MULTIPOLYGON Z (((-11758470.529 4975299.671 -1...
# 1374272  MULTIPOLYGON Z (((-11758470.529 4975299.671 -1...
# 1374274  MULTIPOLYGON Z (((-11758470.529 4975299.671 -1...
#
# [205153 rows x 26 columns]

# %% [markdown]
# ## Merging overlapping treatment activities that occured within three days of each other

# %%
# this only includes sites for western US states
# All treatment activities occur over a unique area, or overlap with another that occurred less than three days before/after
twig_data = gpd.read_file('/oak/stanford/groups/konings/ashdef/TWIG/TWIG_3day_no_overlap/wus_trmts_unique_3day.shp')
twig_data

# %%
twig_data.shape

# %%
# identify overlapping groups
sindex = twig_data.sindex # creating spatial index

# this list will hold sets of indices belonging to the same overlapping group
groups = []
visited = set()

for i, geom in enumerate(twig_data.geometry): # loop over twig polygons
    if i in visited: # geometry is already in a group 
        continue

    # find all geometries that intersect this one
    possible_matches_idx = list(sindex.intersection(geom.bounds))
    matches = twig_data.iloc[possible_matches_idx]
    overlaps = matches[matches.intersects(geom)]

    # initialize the current group
    group = set(overlaps.index)

    # expand the group by checking intersections recursively - used chatGPT for help with this
    changed = True
    while changed:
        changed = False
        new_group = set(group)
        for j in list(group):
            possible = list(sindex.intersection(twig_data.geometry.iloc[j].bounds))
            new_overlaps = twig_data.iloc[possible]
            intersecting = new_overlaps[new_overlaps.intersects(twig_data.geometry.iloc[j])]
            new_group |= set(intersecting.index)
        if new_group != group:
            group = new_group
            changed = True

    groups.append(group)
    visited |= group

# merge
merged_rows = []
for group in groups:
    subset = twig_data.loc[list(group)]

    merged_geom = unary_union(subset.geometry)
    latest_date = subset['treatment_'].max()
    merged_twigs = ", ".join(sorted(set(subset['twig_categ'].fillna("Unknown"))))
    
    # aggregate attributes
    merged_rows.append({
        "geometry": merged_geom,
        "treatment_": latest_date,
        "twig_categ": merged_twigs
    })

# create merged GeoDataFrame
merged_gdf = gpd.GeoDataFrame(merged_rows, crs=twig_data.crs)
merged_gdf.to_file("/oak/stanford/groups/konings/ashdef/TWIG/TWIG_3day_no_overlap/wus_trmts_merged_3day.shp")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # identify overlapping groups
# ----> 2 sindex = twig_data.sindex # creating spatial index
#       4 # this list will hold sets of indices belonging to the same overlapping group
#       5 groups = []
#
# NameError: name 'twig_data' is not defined

# %%
twig_data = gpd.read_file('/oak/stanford/groups/konings/ashdef/TWIG/TWIG_3day_no_overlap/wus_trmts_merged_3day.shp')
twig_data
# Out:
#       treatment_                                        twig_categ  \
# 0     2002-09-01                                        Mechanical
# 1     1990-08-01                                        Mechanical
# 2     2022-07-01  Mechanical, Planned Ignition, Unplanned Ignition
# 3     1993-07-01                                        Mechanical
# 4     1998-04-01                                  Planned Ignition
# ...          ...                                               ...
# 80816 2023-10-30                                        Mechanical
# 80817 2025-10-30                                        Mechanical
# 80818 2010-10-20                                        Mechanical
# 80819 2011-10-19                                  Planned Ignition
# 80820 2022-08-01                                        Mechanical
#
#                                                 geometry
# 0      POLYGON Z ((-12393260.542 5637811.54 -100000, ...
# 1      POLYGON Z ((-12866381.239 5748452.649 -100000,...
# 2      MULTIPOLYGON Z (((-12681223.54 6141885.97 -100...
# 3      POLYGON Z ((-13024599.581 6240766.296 -100000,...
# 4      POLYGON Z ((-11840763.606 5658727.627 -100000,...
# ...                                                  ...
# 80816  POLYGON Z ((-12687623.84 5664566.575 -100000, ...
# 80817  POLYGON Z ((-12686588.196 5660323.458 -100000,...
# 80818  POLYGON Z ((-11829665.679 5012370.196 -100000,...
# 80819  POLYGON Z ((-11813087.771 5067130.862 -100000,...
# 80820  POLYGON Z ((-11899910.354 5038070.745 -100000,...
#
# [80821 rows x 3 columns]

# %%
western_states = ['CA', 'OR', 'WA', 'ID', 'MT', 'WY', 'UT', 'AZ', 'CO', 'NM']

wus_trmts = data[data['state'].isin(western_states)]
wus_trmts.shape
wus_trmts.columns
# Out:
# Index(['unique_id', 'name', 'state', 'acres', 'treatment_date', 'date_source',
#        'identifier_database', 'date_current', 'actual_completion_date',
#        'activity_code', 'activity', 'method', 'equipment', 'category', 'type',
#        'twig_category', 'agency', 'fund_source', 'fund_code', 'total_cost',
#        'cost_per_uom', 'uom', 'error', 'shape_Length', 'shape_Area',
#        'geometry'],
#       dtype='object')

# %%
# spatial indices for treatment polygons
geoms = list(wus_trmts.geometry)
tree = STRtree(geoms)

# %%
wus_trmts['treatment_date'] = pd.to_datetime(wus_trmts['treatment_date'])
# Out:
# /home/users/ashdef/.local/lib/python3.9/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
non_overlapping = [] # list of indices for polygons that aren't overlapping another

overlapping = [] # list of indices for polygons that are overlapping another


#loop over polygons
for i, geom in enumerate(geoms):
    # which polygons maybe intersect?
    possible_matches_idx = tree.query(geom) # this returns indices, not geometries

    # check each possible match
    overlaps = False
    for j in possible_matches_idx:
        if i == j: # skip if the current polygon is being looked at
            continue  

        # if polygons do intersect, check how far apart the treatment dates are
        if geom.intersects(geoms[j]):

            if wus_trmts['treatment_date'].iloc[i].year != wus_trmts['treatment_date'].iloc[j].year: # if the treatments occur in different years, filter them
                overlaps = True
                overlapping.append((i, j))                 
                
            break  

    if not overlaps:
        non_overlapping.append(i) # this will now include intersecting treatments that occurred within the same calendar year

# filter out the original geodataframe
wus_trmts_unique_year = wus_trmts.iloc[non_overlapping]

# %%
wus_trmts_unique_year.to_file("/scratch/users/ashdef/twig/wus_trmts_unique_year.shp")
# Out:
# /tmp/ipykernel_193412/1618430925.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   wus_trmts_unique_year.to_file("/scratch/users/ashdef/twig/wus_trmts_unique_year.shp")
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'treatment_date' to 'treatment_'
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field treatment_ create as date field, though DateTime requested.
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'date_source' to 'date_sourc'
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'identifier_database' to 'identifier'
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'date_current' to 'date_curre'
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field date_curre create as date field, though DateTime requested.
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'actual_completion_date' to 'actual_com'
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field actual_com create as date field, though DateTime requested.
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'activity_code' to 'activity_c'
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'twig_category' to 'twig_categ'
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'fund_source' to 'fund_sourc'
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'cost_per_uom' to 'cost_per_u'
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'shape_Length' to 'shape_Leng'
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 486441000 of field total_cost of feature 117456 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 271369848.17492718 of field shape_Area of feature 122494 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 271369848.17492718 of field shape_Area of feature 122496 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 114591594.12734444 of field shape_Area of feature 122497 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1040556676.2384692 of field shape_Area of feature 126639 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 679759746.13049245 of field shape_Area of feature 145444 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 165536936.34643292 of field shape_Area of feature 174183 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 101560398.58600429 of field shape_Area of feature 176533 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 180925917.7832039 of field shape_Area of feature 177470 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 121060094.1478575 of field shape_Area of feature 177831 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 257828557.88573274 of field shape_Area of feature 179048 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 163769212.649113 of field shape_Area of feature 179516 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 176664702.95304316 of field shape_Area of feature 179517 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 125268818.49842121 of field shape_Area of feature 179518 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 261338841.63164049 of field shape_Area of feature 179519 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 112671629.93107618 of field shape_Area of feature 179521 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 172597204.52339754 of field shape_Area of feature 179522 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 115823312.09318641 of field shape_Area of feature 179979 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 125541435.16782238 of field shape_Area of feature 181118 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 200061442.13889119 of field shape_Area of feature 181727 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 164796518.08584273 of field shape_Area of feature 182463 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 182550448.96810463 of field shape_Area of feature 182501 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 142443512.25135407 of field shape_Area of feature 183848 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 113114308.79653232 of field shape_Area of feature 183885 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 178333930.33843213 of field shape_Area of feature 183997 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1020767828.755384 of field shape_Area of feature 184339 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 185678311.94318396 of field shape_Area of feature 186476 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 149893507.99346247 of field shape_Area of feature 188122 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 130439396.97490282 of field shape_Area of feature 188508 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 112450114.34174129 of field shape_Area of feature 189451 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 220830437.33229825 of field shape_Area of feature 193591 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 106272022.57814845 of field shape_Area of feature 193755 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 107485495.23303689 of field shape_Area of feature 194586 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 164088685.72024676 of field shape_Area of feature 196778 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 164088685.72024676 of field shape_Area of feature 196779 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 105284225.89475408 of field shape_Area of feature 197109 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 105284225.89475408 of field shape_Area of feature 197110 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 761443056.94960737 of field shape_Area of feature 198855 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 109592415.99377863 of field shape_Area of feature 205482 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 141818918.9109475 of field shape_Area of feature 206824 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 141818918.9109475 of field shape_Area of feature 206825 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 162413035.73941708 of field shape_Area of feature 207159 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 162413035.73941708 of field shape_Area of feature 207160 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 157904617.82690918 of field shape_Area of feature 213792 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 208556490 of field total_cost of feature 213967 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 169791183.4295955 of field shape_Area of feature 213967 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 153691260 of field total_cost of feature 217507 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 202118285.6193648 of field shape_Area of feature 218485 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 486441000 of field total_cost of feature 220573 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 103277773.62047634 of field shape_Area of feature 221093 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 271369848.17492718 of field shape_Area of feature 235076 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 271369848.17492718 of field shape_Area of feature 235094 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 271369848.17492718 of field shape_Area of feature 235103 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 271369848.17492718 of field shape_Area of feature 235109 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 271369848.17492718 of field shape_Area of feature 235129 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 214413070.42399999 of field total_cost of feature 237343 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 310633980.80837029 of field shape_Area of feature 237343 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 214413070.42399999 of field total_cost of feature 237384 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 310633980.80837029 of field shape_Area of feature 237384 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 214413070.42399999 of field total_cost of feature 237385 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 310633980.80837029 of field shape_Area of feature 237385 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 214413070.42399999 of field total_cost of feature 237595 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 310633980.80837029 of field shape_Area of feature 237595 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 131530978.97325122 of field shape_Area of feature 242706 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 121055898.31812391 of field shape_Area of feature 243533 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 281446766.27409136 of field shape_Area of feature 243534 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 206206494.06623197 of field shape_Area of feature 244294 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 105985708.27985971 of field shape_Area of feature 247750 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 191455291.7770015 of field shape_Area of feature 259813 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 153521381.56078854 of field shape_Area of feature 263252 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 193788488.77884606 of field shape_Area of feature 263761 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 121729565.08752705 of field shape_Area of feature 264081 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 172174029.39163044 of field shape_Area of feature 264273 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 131798598.61918792 of field shape_Area of feature 264421 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 161055469.27974799 of field shape_Area of feature 265853 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 165413149.90766165 of field shape_Area of feature 267446 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 113712003.90000001 of field total_cost of feature 268136 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 239613046.57086518 of field shape_Area of feature 270591 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 143408581.08377647 of field shape_Area of feature 272192 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 496511097.47144783 of field shape_Area of feature 272581 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 118310100.52216557 of field shape_Area of feature 273951 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 118310100.52216557 of field shape_Area of feature 273952 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 118310100.52216557 of field shape_Area of feature 274014 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 125965474.98024252 of field shape_Area of feature 275834 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 183200505.85536662 of field shape_Area of feature 279915 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 107739649.84242167 of field shape_Area of feature 281157 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/users/ashdef/.local/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 106748523.12106916 of field shape_Area of feature 281307 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
